# %% [markdown]
# Hi hello 로 문자주면 다음 문자를 예측하기

# %%
import tensorflow as tf
import numpy as np
tf.set_random_seed(777)

# %%
# h, i, e, l, o 를 one hot encoding 으로 표현
# voc index
h = [1,0,0,0,0]
i = [0,1,0,0,0]
e = [0,0,1,0,0]
l = [0,0,0,1,0]
o = [0,0,0,0,1]

# %%
# input_dim = 5
# sequence_length = 6
# hidden_dim = 5 (rnn_size)
# batch_size = 1
num_classes = 5
hidden_size = 5
input_dim = 5
batch_size = 1
sequence_length = 6
learning_rate = 0.1

# %%
idx2char = ['h','i','e','l','o']
x_data = [[0,1,0,2,3,3]] # hihell
x_one_hot = [[h,i,h,e,l,l]] # hihell
y_data = [[1,0,2,3,3,4]] # ihello

X = tf.placeholder(tf.float32, [None, sequence_length, input_dim])
Y = tf.placeholder(tf.int32, [None, sequence_length])

cell = tf.contrib.rnn.BasicLSTMCell(num_units=hidden_size, state_is_tuple=True)
initial_state = cell.zero_state(batch_size, tf.float32)
outputs, _states = tf.nn.dynamic_rnn(cell, X, initial_state=initial_state, dtype=tf.float32)

X_for_fc = tf.reshape(outputs, [-1, hidden_size])
outputs = tf.contrib.layers.fully_connected(inputs=X_for_fc, num_outputs=num_classes, activation_fn=None)

outputs = tf.reshape(outputs, [batch_size, sequence_length, num_classes])

weights = tf.ones([batch_size, sequence_length])
sequence_loss = tf.contrib.seq2seq.sequence_loss(logits=outputs, targets=Y, weights=weights)
loss = tf.reduce_mean(sequence_loss)
train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

prediction = tf.argmax(outputs, axis=2)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(50):
        l, _ = sess.run([loss, train], feed_dict={X: x_one_hot, Y: y_data})
        result = sess.run(prediction, feed_dict={X: x_one_hot})
        print(i, "loss:", l, "prediction: ", result, "true Y: ", y_data)

        # print char using dic
        result_str = [idx2char[c] for c in np.squeeze(result)]
        print("\tPrediction str: ", ''.join(result_str))
# Out:
# 0 loss: 1.6231518 prediction:  [[3 3 3 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  llllll
# 1 loss: 1.5293372 prediction:  [[3 3 3 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  llllll
# 2 loss: 1.4494089 prediction:  [[3 3 3 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  llllll
# 3 loss: 1.3569936 prediction:  [[3 3 3 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  llllll
# 4 loss: 1.257336 prediction:  [[3 3 3 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  llllll
# 5 loss: 1.1463764 prediction:  [[1 2 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ieelll
# 6 loss: 1.0323033 prediction:  [[1 2 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ieelll
# 7 loss: 0.92284536 prediction:  [[1 0 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihelll
# 8 loss: 0.80993766 prediction:  [[1 0 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihelll
# 9 loss: 0.695903 prediction:  [[1 0 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihelll
# 10 loss: 0.5858249 prediction:  [[1 0 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihelll
# 11 loss: 0.48857087 prediction:  [[1 0 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihelll
# 12 loss: 0.40631565 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 13 loss: 0.33545482 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 14 loss: 0.2731111 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 15 loss: 0.22032294 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 16 loss: 0.17922954 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 17 loss: 0.14868347 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 18 loss: 0.124624506 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 19 loss: 0.10406314 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 20 loss: 0.08637347 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 21 loss: 0.07203849 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 22 loss: 0.060964596 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 23 loss: 0.052055955 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 24 loss: 0.04418262 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 25 loss: 0.03701692 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 26 loss: 0.030772287 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 27 loss: 0.025594886 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 28 loss: 0.021389317 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 29 loss: 0.017978955 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 30 loss: 0.015234856 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 31 loss: 0.013069581 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 32 loss: 0.011389375 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 33 loss: 0.01008512 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 34 loss: 0.009052931 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 35 loss: 0.008211732 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 36 loss: 0.0075057163 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 37 loss: 0.0068990206 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 38 loss: 0.0063689793 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 39 loss: 0.0059010433 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 40 loss: 0.0054853633 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 41 loss: 0.005114781 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 42 loss: 0.0047837766 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 43 loss: 0.0044879457 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 44 loss: 0.0042233486 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 45 loss: 0.00398669 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 46 loss: 0.003774786 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 47 loss: 0.003585158 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 48 loss: 0.0034152027 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 49 loss: 0.003262727 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
